# %% [markdown]
# # Interpolate

# %%
import pandas as pd

var =pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\stock_data1.csv")
var
# Out:
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1  ELECTTHERM          Electrotherm (India) Limited        473907.0
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.          5754.0
# 2     3     HINDCON             Hindcon Chemicals Limited        304759.0
# 3     4  GKWLIMITED                           GKW Limited         21375.0
# 4     5  21STCENMGM         21st Century Management Serv.        110375.0
# 5     6    ALPHAGEO              Alphageo (India) Limited             NaN
# 6     7         NaN           Uniphos Enterprises Limited             NaN
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.             NaN
# 8     9  SKMEGGPROD  SKM Egg Products Export (India) Lim.             NaN
# 9    10   SWELECTES                                   NaN             NaN
# 10   11   NAHARPOLY              Nahar Poly Films Limited         38574.0
# 11   12  PODDARHOUS        Poddar Housing and Development             1.0
# ...

# %%
var.interpolate()
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_5780\1566664964.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate()
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1  ELECTTHERM          Electrotherm (India) Limited   473907.000000
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.     5754.000000
# 2     3     HINDCON             Hindcon Chemicals Limited   304759.000000
# 3     4  GKWLIMITED                           GKW Limited    21375.000000
# 4     5  21STCENMGM         21st Century Management Serv.   110375.000000
# 5     6    ALPHAGEO              Alphageo (India) Limited    98408.166667
# 6     7         NaN           Uniphos Enterprises Limited    86441.333333
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.    74474.500000
# ...

# %%
var.interpolate(method="linear",axis=0)
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_5780\3195347084.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(method="linear",axis=0)
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1  ELECTTHERM          Electrotherm (India) Limited   473907.000000
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.     5754.000000
# 2     3     HINDCON             Hindcon Chemicals Limited   304759.000000
# 3     4  GKWLIMITED                           GKW Limited    21375.000000
# 4     5  21STCENMGM         21st Century Management Serv.   110375.000000
# 5     6    ALPHAGEO              Alphageo (India) Limited    98408.166667
# 6     7         NaN           Uniphos Enterprises Limited    86441.333333
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.    74474.500000
# ...

# %%
var.interpolate(limit_direction="both",limit=2)
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_5780\3871155077.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   var.interpolate(limit_direction="both",limit=2)
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1  ELECTTHERM          Electrotherm (India) Limited   473907.000000
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.     5754.000000
# 2     3     HINDCON             Hindcon Chemicals Limited   304759.000000
# 3     4  GKWLIMITED                           GKW Limited    21375.000000
# 4     5  21STCENMGM         21st Century Management Serv.   110375.000000
# 5     6    ALPHAGEO              Alphageo (India) Limited    98408.166667
# 6     7         NaN           Uniphos Enterprises Limited    86441.333333
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.             NaN
# ...

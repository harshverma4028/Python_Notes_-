# %% [markdown]
# # Replace

# %%
import pandas as pd

var =pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\stock_data.csv")
var
# Out:
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1  ELECTTHERM          Electrotherm (India) Limited          473907
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.            5754
# 2     3     HINDCON             Hindcon Chemicals Limited          304759
# 3     4  GKWLIMITED                           GKW Limited           21375
# 4     5  21STCENMGM         21st Century Management Serv.          110375
# 5     6    ALPHAGEO              Alphageo (India) Limited               1
# 6     7    UNIENTER           Uniphos Enterprises Limited               1
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.               1
# 8     9  SKMEGGPROD  SKM Egg Products Export (India) Lim.               1
# 9    10   SWELECTES        Swelect Energy Systems Limited               1
# 10   11   NAHARPOLY              Nahar Poly Films Limited           38574
# 11   12  PODDARHOUS        Poddar Housing and Development               1
# ...

# %%
var.replace(to_replace=1,value=22)
# Out:
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0    22  ELECTTHERM          Electrotherm (India) Limited          473907
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.            5754
# 2     3     HINDCON             Hindcon Chemicals Limited          304759
# 3     4  GKWLIMITED                           GKW Limited           21375
# 4     5  21STCENMGM         21st Century Management Serv.          110375
# 5     6    ALPHAGEO              Alphageo (India) Limited              22
# 6     7    UNIENTER           Uniphos Enterprises Limited              22
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.              22
# 8     9  SKMEGGPROD  SKM Egg Products Export (India) Lim.              22
# 9    10   SWELECTES        Swelect Energy Systems Limited              22
# 10   11   NAHARPOLY              Nahar Poly Films Limited           38574
# 11   12  PODDARHOUS        Poddar Housing and Development              22
# ...

# %%
 var.replace(to_replace="ELECTTHERM",value=" sapna dekhna acchi baat hai")
# Out:
#     NO.                        SYMBOL                              SECURITY  \
# 0     1   sapna dekhna acchi baat hai          Electrotherm (India) Limited
# 1     2                        NBIFIN      N. B. I. Industrial Finance Com.
# 2     3                       HINDCON             Hindcon Chemicals Limited
# 3     4                    GKWLIMITED                           GKW Limited
# 4     5                    21STCENMGM         21st Century Management Serv.
# 5     6                      ALPHAGEO              Alphageo (India) Limited
# 6     7                      UNIENTER           Uniphos Enterprises Limited
# 7     8                    JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.
# 8     9                    SKMEGGPROD  SKM Egg Products Export (India) Lim.
# 9    10                     SWELECTES        Swelect Energy Systems Limited
# 10   11                     NAHARPOLY              Nahar Poly Films Limited
# ...

# %%
var.replace([1,2,3,4,5,6,7,8,9],39)

# %%
var.replace("[A-Z]","PnP",regex=True)
# Out:
#     NO.                          SYMBOL  \
# 0     1  PnPPnPPnPPnPPnPPnPPnPPnPPnPPnP
# 1     2              PnPPnPPnPPnPPnPPnP
# 2     3           PnPPnPPnPPnPPnPPnPPnP
# 3     4  PnPPnPPnPPnPPnPPnPPnPPnPPnPPnP
# 4     5      21PnPPnPPnPPnPPnPPnPPnPPnP
# 5     6        PnPPnPPnPPnPPnPPnPPnPPnP
# 6     7        PnPPnPPnPPnPPnPPnPPnPPnP
# 7     8  PnPPnPPnPPnPPnPPnPPnPPnPPnPPnP
# 8     9  PnPPnPPnPPnPPnPPnPPnPPnPPnPPnP
# 9    10     PnPPnPPnPPnPPnPPnPPnPPnPPnP
# 10   11     PnPPnPPnPPnPPnPPnPPnPPnPPnP
# 11   12  PnPPnPPnPPnPPnPPnPPnPPnPPnPPnP
# 12   13                    PnPPnPPnPPnP
# 13   14                 PnPPnPPnPPnP123
#
#                                              SECURITY  TODAY - VOLUME  \
# 0                  PnPlectrotherm (PnPndia) PnPimited          473907
# 1        PnP. PnP. PnP. PnPndustrial PnPinance PnPom.            5754
# 2                     PnPindcon PnPhemicals PnPimited          304759
# 3                                 PnPPnPPnP PnPimited           21375
# ...

# %% [markdown]
# # Using Dictonary

# %%
var.replace({"SYMBOL":'[A-Z]'},22,regex=True)
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_1396\1996798884.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   var.replace({"SYMBOL":'[A-Z]'},22,regex=True)
#     NO.  SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1      22          Electrotherm (India) Limited          473907
# 1     2      22      N. B. I. Industrial Finance Com.            5754
# 2     3      22             Hindcon Chemicals Limited          304759
# 3     4      22                           GKW Limited           21375
# 4     5      22         21st Century Management Serv.          110375
# 5     6      22              Alphageo (India) Limited               1
# 6     7      22           Uniphos Enterprises Limited               1
# ...

# %%
var.replace(1,method="bfill")
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_1396\1975081475.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var.replace(1,method="bfill")
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     2  ELECTTHERM          Electrotherm (India) Limited          473907
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.            5754
# 2     3     HINDCON             Hindcon Chemicals Limited          304759
# 3     4  GKWLIMITED                           GKW Limited           21375
# 4     5  21STCENMGM         21st Century Management Serv.          110375
# 5     6    ALPHAGEO              Alphageo (India) Limited           38574
# 6     7    UNIENTER           Uniphos Enterprises Limited           38574
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.           38574
# 8     9  SKMEGGPROD  SKM Egg Products Export (India) Lim.           38574
# ...

# %%
var.replace(1,method="ffill",limit=3)
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_1396\271419978.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var.replace(1,method="ffill",limit=3)
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1  ELECTTHERM          Electrotherm (India) Limited          473907
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.            5754
# 2     3     HINDCON             Hindcon Chemicals Limited          304759
# 3     4  GKWLIMITED                           GKW Limited           21375
# 4     5  21STCENMGM         21st Century Management Serv.          110375
# 5     6    ALPHAGEO              Alphageo (India) Limited          110375
# 6     7    UNIENTER           Uniphos Enterprises Limited          110375
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.          110375
# 8     9  SKMEGGPROD  SKM Egg Products Export (India) Lim.               1
# ...

# %%
var.replace(1,method="ffill",limit=3,inplace=True)
var
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_1396\3407534592.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var.replace(1,method="ffill",limit=3,inplace=True)
#     NO.      SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0     1  ELECTTHERM          Electrotherm (India) Limited          473907
# 1     2      NBIFIN      N. B. I. Industrial Finance Com.            5754
# 2     3     HINDCON             Hindcon Chemicals Limited          304759
# 3     4  GKWLIMITED                           GKW Limited           21375
# 4     5  21STCENMGM         21st Century Management Serv.          110375
# 5     6    ALPHAGEO              Alphageo (India) Limited          110375
# 6     7    UNIENTER           Uniphos Enterprises Limited          110375
# 7     8  JAGSNPHARM        Jagsonpal Pharmaceuticals Lim.          110375
# ...

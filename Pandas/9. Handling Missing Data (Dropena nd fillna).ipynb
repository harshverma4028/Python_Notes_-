# %% [markdown]
# # dropna & fillna

# %%
import pandas as pd

var =pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\clv_data.csv")
var
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 0            0   0   NaN    Male  126895.0              14.0  San Francisco
# 1            1   1   NaN    Male  161474.0              14.0          Tokyo
# 2            2   2  24.0    Male  104723.0              34.0         London
# 3            3   3  29.0     NaN       NaN              28.0            NaN
# 4            4   4  18.0  Female       NaN              26.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 6            6   6   NaN    Male   51679.0              30.0          Tokyo
# 7            7   7   NaN  Female   53341.0              43.0  San Francisco
# 8            8   8  46.0     NaN  129157.0              23.0            NaN
# 9            9   9  49.0  Female       NaN              19.0          Tokyo
# 10          10  10   NaN    Male  159506.0               7.0            NaN
# ...

# %%
var.dropna()
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 2            2   2  24.0    Male  104723.0              34.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 12          12  12  12.0    Male  130521.0              12.0         London
# 16          16  16  19.0  Female   51434.0              18.0  New York City
# 17          17  17  27.0  Female  177582.0               2.0         London
#
#     purchases
# 2         1.0
# 5         0.0
# 12        1.0
# 16        0.0
# 17        0.0

# %%
var.dropna(how="all")
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 0            0   0   NaN    Male  126895.0              14.0  San Francisco
# 1            1   1   NaN    Male  161474.0              14.0          Tokyo
# 2            2   2  24.0    Male  104723.0              34.0         London
# 3            3   3  29.0     NaN       NaN              28.0            NaN
# 4            4   4  18.0  Female       NaN              26.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 6            6   6   NaN    Male   51679.0              30.0          Tokyo
# 7            7   7   NaN  Female   53341.0              43.0  San Francisco
# 8            8   8  46.0     NaN  129157.0              23.0            NaN
# 9            9   9  49.0  Female       NaN              19.0          Tokyo
# 10          10  10   NaN    Male  159506.0               7.0            NaN
# ...

# %%
var.dropna(subset=["gender"])
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 0            0   0   NaN    Male  126895.0              14.0  San Francisco
# 1            1   1   NaN    Male  161474.0              14.0          Tokyo
# 2            2   2  24.0    Male  104723.0              34.0         London
# 4            4   4  18.0  Female       NaN              26.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 6            6   6   NaN    Male   51679.0              30.0          Tokyo
# 7            7   7   NaN  Female   53341.0              43.0  San Francisco
# 9            9   9  49.0  Female       NaN              19.0          Tokyo
# 10          10  10   NaN    Male  159506.0               7.0            NaN
# 12          12  12  12.0    Male  130521.0              12.0         London
# 13          13  13   NaN    Male  105418.0              13.0          Miami
# ...

# %%
var.dropna(inplace=True)
var
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 2            2   2  24.0    Male  104723.0              34.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 12          12  12  12.0    Male  130521.0              12.0         London
# 16          16  16  19.0  Female   51434.0              18.0  New York City
# 17          17  17  27.0  Female  177582.0               2.0         London
#
#     purchases
# 2         1.0
# 5         0.0
# 12        1.0
# 16        0.0
# 17        0.0

# %%
var.dropna(thresh=2)
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 2            2   2  24.0    Male  104723.0              34.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 12          12  12  12.0    Male  130521.0              12.0         London
# 16          16  16  19.0  Female   51434.0              18.0  New York City
# 17          17  17  27.0  Female  177582.0               2.0         London
#
#     purchases
# 2         1.0
# 5         0.0
# 12        1.0
# 16        0.0
# 17        0.0

# %%
var.fillna("Vidrohi")
# Out:
#     Unnamed: 0  id      age   gender    income days_on_platform  \
# 0            0   0  Vidrohi     Male  126895.0             14.0
# 1            1   1  Vidrohi     Male  161474.0             14.0
# 2            2   2     24.0     Male  104723.0             34.0
# 3            3   3     29.0  Vidrohi   Vidrohi             28.0
# 4            4   4     18.0   Female   Vidrohi             26.0
# 5            5   5     23.0     Male   12315.0             14.0
# 6            6   6  Vidrohi     Male   51679.0             30.0
# 7            7   7  Vidrohi   Female   53341.0             43.0
# 8            8   8     46.0  Vidrohi  129157.0             23.0
# 9            9   9     49.0   Female   Vidrohi             19.0
# 10          10  10  Vidrohi     Male  159506.0              7.0
# 11          11  11  Vidrohi  Vidrohi   Vidrohi             30.0
# 12          12  12     12.0     Male  130521.0             12.0
# 13          13  13  Vidrohi     Male  105418.0             13.0
# ...

# %%
var.fillna({"age":"202","city":"Khagaria"})
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 0            0   0   202    Male  126895.0              14.0  San Francisco
# 1            1   1   202    Male  161474.0              14.0          Tokyo
# 2            2   2  24.0    Male  104723.0              34.0         London
# 3            3   3  29.0     NaN       NaN              28.0       Khagaria
# 4            4   4  18.0  Female       NaN              26.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 6            6   6   202    Male   51679.0              30.0          Tokyo
# 7            7   7   202  Female   53341.0              43.0  San Francisco
# 8            8   8  46.0     NaN  129157.0              23.0       Khagaria
# 9            9   9  49.0  Female       NaN              19.0          Tokyo
# 10          10  10   202    Male  159506.0               7.0       Khagaria
# ...

# %%
var.fillna(method="ffill")
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_16300\3062787689.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var.fillna(method="ffill")
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 0            0   0   NaN    Male  126895.0              14.0  San Francisco
# 1            1   1   NaN    Male  161474.0              14.0          Tokyo
# 2            2   2  24.0    Male  104723.0              34.0         London
# 3            3   3  29.0    Male  104723.0              28.0         London
# 4            4   4  18.0  Female  104723.0              26.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 6            6   6  23.0    Male   51679.0              30.0          Tokyo
# 7            7   7  23.0  Female   53341.0              43.0  San Francisco
# ...

# %%
var.fillna(method="ffill",axis=1)
# Out:
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_16300\2684882124.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var.fillna(method="ffill",axis=1)
# C:\Users\Harsh Verma\AppData\Local\Temp\ipykernel_16300\2684882124.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   var.fillna(method="ffill",axis=1)
#    Unnamed: 0   id   age  gender    income days_on_platform           city  \
# 0           0    0     0    Male  126895.0             14.0  San Francisco
# 1           1    1     1    Male  161474.0             14.0          Tokyo
# 2           2    2  24.0    Male  104723.0             34.0         London
# ...

# %%
var.fillna("python",limit=2)
var
# Out:
#     Unnamed: 0  id   age  gender    income  days_on_platform           city  \
# 0            0   0   NaN    Male  126895.0              14.0  San Francisco
# 1            1   1   NaN    Male  161474.0              14.0          Tokyo
# 2            2   2  24.0    Male  104723.0              34.0         London
# 3            3   3  29.0     NaN       NaN              28.0            NaN
# 4            4   4  18.0  Female       NaN              26.0         London
# 5            5   5  23.0    Male   12315.0              14.0  New York City
# 6            6   6   NaN    Male   51679.0              30.0          Tokyo
# 7            7   7   NaN  Female   53341.0              43.0  San Francisco
# 8            8   8  46.0     NaN  129157.0              23.0            NaN
# 9            9   9  49.0  Female       NaN              19.0          Tokyo
# 10          10  10   NaN    Male  159506.0               7.0            NaN
# ...

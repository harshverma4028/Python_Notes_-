# %% [markdown]
# # Read csv

# %%
import pandas as pd

csv_1=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv")
csv_1
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2023                     Level 1                   AA
# 1   2023                     Level 1                   AA
# 2   2023                     Level 1                   AA
# 3   2023                     Level 1                   AA
# 4   2023                     Level 1                   AA
# ..   ...                         ...                  ...
# 93  2023                     Level 3                 AA12
# 94  2023                     Level 3                 AA12
# 95  2023                     Level 3                 AA12
# 96  2023                     Level 3                 AA12
# 97  2023                     Level 3                 AA12
#
#                     Industry_name_NZSIOC               Units Variable_code  \
# 0      Agriculture, Forestry and Fishing  Dollars (millions)           H01
# 1      Agriculture, Forestry and Fishing  Dollars (millions)           H04
# ...

# %%
csv_2=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",nrows=2)
csv_2
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0  2023                     Level 1                   AA
# 1  2023                     Level 1                   AA
#
#                 Industry_name_NZSIOC               Units Variable_code  \
# 0  Agriculture, Forestry and Fishing  Dollars (millions)           H01
# 1  Agriculture, Forestry and Fishing  Dollars (millions)           H04
#
#                  Variable_name      Variable_category  Value  \
# 0                 Total income  Financial performance  54462
# 1  Sales of goods and services  Financial performance  51472
#
#   Industry_code_ANZSIC06
# 0    ANZSIC06 division A
# 1    ANZSIC06 division A

# %%
csv_3=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",usecols=[0,6],skiprows=[0,1,3,4])
csv_3
# Out:
#     2023        Sales of goods and services
# 0   2023               Non-operating income
# 1   2023                  Total expenditure
# 2   2023             Interest and donations
# 3   2023                     Indirect taxes
# 4   2023                       Depreciation
# ..   ...                                ...
# 89  2023  Interest, dividends and donations
# 90  2023               Non-operating income
# 91  2023                  Total expenditure
# 92  2023             Interest and donations
# 93  2023                     Indirect taxes
#
# [94 rows x 2 columns]

# %% [markdown]
# # Changing index or Header to another rows

# %% [markdown]
# ###### csv_4=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",index_col="Industry_name_NZSIOC")
# csv_4

# %%
csv_5=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",header=2)
csv_5
# Out:
#     2023  Level 1    AA     Agriculture, Forestry and Fishing  \
# 0   2023  Level 1    AA     Agriculture, Forestry and Fishing
# 1   2023  Level 1    AA     Agriculture, Forestry and Fishing
# 2   2023  Level 1    AA     Agriculture, Forestry and Fishing
# 3   2023  Level 1    AA     Agriculture, Forestry and Fishing
# 4   2023  Level 1    AA     Agriculture, Forestry and Fishing
# ..   ...      ...   ...                                   ...
# 91  2023  Level 3  AA12  Sheep, Beef Cattle and Grain Farming
# 92  2023  Level 3  AA12  Sheep, Beef Cattle and Grain Farming
# 93  2023  Level 3  AA12  Sheep, Beef Cattle and Grain Farming
# 94  2023  Level 3  AA12  Sheep, Beef Cattle and Grain Farming
# 95  2023  Level 3  AA12  Sheep, Beef Cattle and Grain Farming
#
#     Dollars (millions)  H04               Sales of goods and services  \
# 0   Dollars (millions)  H05         Interest, dividends and donations
# 1   Dollars (millions)  H06  Government funding, grants and subsidies
# ...

# %%
csv_6=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",names=["col","col_1","col_2","col_3","col_4","col_5","col_6","col_7","col_8","col_9"])
csv_6
# Out:
#      col                        col_1                 col_2  \
# 0   Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1   2023                      Level 1                    AA
# 2   2023                      Level 1                    AA
# 3   2023                      Level 1                    AA
# 4   2023                      Level 1                    AA
# ..   ...                          ...                   ...
# 94  2023                      Level 3                  AA12
# 95  2023                      Level 3                  AA12
# 96  2023                      Level 3                  AA12
# 97  2023                      Level 3                  AA12
# 98  2023                      Level 3                  AA12
#
#                                    col_3               col_4          col_5  \
# 0                   Industry_name_NZSIOC               Units  Variable_code
# 1      Agriculture, Forestry and Fishing  Dollars (millions)            H01
# ...

# %%
csv_7=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",header=None, prefix="col")
csv_7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 csv_7=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",header=None, prefix="col")
#       2 csv_7
#
# TypeError: read_csv() got an unexpected keyword argument 'prefix'

# %%
csv_7=pd.read_csv("C:\\Users\\Harsh Verma\\Documents\\Panda\\annual.csv",dtype={"Value":"float"})
csv_7
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2023                     Level 1                   AA
# 1   2023                     Level 1                   AA
# 2   2023                     Level 1                   AA
# 3   2023                     Level 1                   AA
# 4   2023                     Level 1                   AA
# ..   ...                         ...                  ...
# 93  2023                     Level 3                 AA12
# 94  2023                     Level 3                 AA12
# 95  2023                     Level 3                 AA12
# 96  2023                     Level 3                 AA12
# 97  2023                     Level 3                 AA12
#
#                     Industry_name_NZSIOC               Units Variable_code  \
# 0      Agriculture, Forestry and Fishing  Dollars (millions)           H01
# 1      Agriculture, Forestry and Fishing  Dollars (millions)           H04
# ...

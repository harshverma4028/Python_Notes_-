# %%
import matplotlib.pyplot as plt
import numpy as np 
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [20 40 35 53 24 12 50 37 57 24 27 39 17 55 48 10 59 33 11 45 21 54 47 47
#  51 54 29 33 21 53 48 34 25 52 59 42 12 41 20 55 42 38 29 51 44 40 56 28
#  26 52]

# %%
no=[32, 57, 33, 28, 34, 38, 38, 18, 24, 11,
    49, 13, 37, 53, 43, 25, 32, 13, 28, 22, 49, 39, 37, 11, 51, 31, 44, 55, 53, 15,
    33, 49, 35, 34, 33, 25, 58, 54, 43, 40, 38, 14, 26, 21, 31, 39, 11, 38, 26, 29]
l=[10,20,30,40,50,60]


plt.hist(no,color="m",align="left",histtype="bar",edgecolor="b",rwidth=0.8,log=True,label="python")

#,cumulative=-1

plt.title("Wscube")
plt.xlabel("python")

plt.axvline(45,color="r")

plt.grid()
plt.legend()
plt.ylabel("No")
plt.show()
